# %%
import pandas as pd

# %%
df=pd.read_csv("employee_data.csv")
print(df,type(df))
# Out:
#    ID     Name  Age Department  Salary
# 0   1    Alice   25         HR   55000
# 1   2      Bob   32         IT   72000
# 2   3  Charlie   28    Finance   48000
# 3   4    David   45  Marketing   91000
# 4   5      Eva   38         IT   65000
# 5   6    Frank   29    Finance   50000
# 6   7    Grace   41         HR   82000
# 7   8   Hannah   26  Marketing   47000
# 8   9      Ian   35         IT   75000
# 9  10    Julia   30    Finance   60000 <class 'pandas.core.frame.DataFrame'>

# %%
df.head()
# Out:
#    ID     Name  Age Department  Salary
# 0   1    Alice   25         HR   55000
# 1   2      Bob   32         IT   72000
# 2   3  Charlie   28    Finance   48000
# 3   4    David   45  Marketing   91000
# 4   5      Eva   38         IT   65000

# %%
df.tail()
# Out:
#    ID    Name  Age Department  Salary
# 5   6   Frank   29    Finance   50000
# 6   7   Grace   41         HR   82000
# 7   8  Hannah   26  Marketing   47000
# 8   9     Ian   35         IT   75000
# 9  10   Julia   30    Finance   60000

# %%
df.shape
# Out:
# (10, 5)

# %%
df.describe()
# Out:
#              ID        Age        Salary
# count  10.00000  10.000000     10.000000
# mean    5.50000  32.900000  64500.000000
# std     3.02765   6.674162  15182.226451
# min     1.00000  25.000000  47000.000000
# 25%     3.25000  28.250000  51250.000000
# 50%     5.50000  31.000000  62500.000000
# 75%     7.75000  37.250000  74250.000000
# max    10.00000  45.000000  91000.000000

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10 entries, 0 to 9
# Data columns (total 5 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   ID          10 non-null     int64
#  1   Name        10 non-null     object
#  2   Age         10 non-null     int64
#  3   Department  10 non-null     object
#  4   Salary      10 non-null     int64
# dtypes: int64(3), object(2)
# memory usage: 532.0+ bytes

# %%
df=pd.read_csv("globalAirQuality.csv")
df.describe()
# Out:
#            latitude     longitude          pm25          pm10           no2  \
# count  18000.000000  18000.000000  18000.000000  18000.000000  18000.000000
# mean      23.065980     37.655560     40.369131     70.152228     32.055176
# std       26.156536     78.600701     17.647450     24.999440     13.820680
# min      -37.814000   -123.121000      0.025000      0.061000      0.013000
# 25%       12.972000      2.352000     27.904500     53.125500     22.362500
# 50%       29.232000     42.146000     40.286500     69.961000     32.019500
# 75%       41.008000    103.820000     52.436250     87.256500     41.364250
# max       60.170000    174.763000    115.683000    161.810000     90.019000
#
#                 so2            o3            co           aqi   temperature  \
# count  18000.000000  18000.000000  18000.000000  18000.000000  18000.000000
# mean       6.035508     48.065100      0.800595    104.645556     21.510251
# ...

# %%
s = pd.Series([23, 24, 25, 26])
print(s)
print(type(s)) # Indexing print(s[0]) # 23 print(s[2]) # 25
print(s.index)# all labels
# Out:
# 0    23
# 1    24
# 2    25
# 3    26
# dtype: int64
# <class 'pandas.core.series.Series'>
# RangeIndex(start=0, stop=4, step=1)

# %%
s=pd.Series([1,2,3,4,5])
s[0]=100
print(s)
changed_s=s.drop(1)
print(changed_s)
print(s)
# Out:
# 0    100
# 1      2
# 2      3
# 3      4
# 4      5
# dtype: int64
# 0    100
# 2      3
# 3      4
# 4      5
# dtype: int64
# 0    100
# 1      2
# 2      3
# 3      4
# 4      5
# dtype: int64

# %%
df.head()
# Out:
#                     timestamp country      city  latitude  longitude    pm25  \
# 0  2025-11-04 18:25:17.554219      US  New York    40.713    -74.006  50.295
# 1  2025-11-04 19:25:17.554219      US  New York    40.713    -74.006  32.083
# 2  2025-11-04 20:25:17.554219      US  New York    40.713    -74.006  42.250
# 3  2025-11-04 21:25:17.554219      US  New York    40.713    -74.006  30.403
# 4  2025-11-04 22:25:17.554219      US  New York    40.713    -74.006  21.083
#
#       pm10     no2    so2      o3     co  aqi  temperature  humidity  \
# 0  108.938  27.998  6.539  52.568  1.096  108       18.504    70.168
# 1   63.043  36.120  4.021  43.536  1.075   90        5.838    80.088
# 2   82.553  26.935  9.538  23.320  0.977   84       31.833    62.783
# 3   79.951  63.536  7.609  31.369  0.230  158       23.140    89.153
# 4   66.423  38.997  6.919  45.615  1.085   97       13.632    76.499
#
#    wind_speed
# 0       3.725
# 1       8.969
# 2       9.650
# 3       8.956
# ...

# %%
df.tail()
# Out:
#                         timestamp country    city  latitude  longitude  \
# 17995  2025-11-19 13:25:17.554219      CH  Zurich    47.377      8.542
# 17996  2025-11-19 14:25:17.554219      CH  Zurich    47.377      8.542
# 17997  2025-11-19 15:25:17.554219      CH  Zurich    47.377      8.542
# 17998  2025-11-19 16:25:17.554219      CH  Zurich    47.377      8.542
# 17999  2025-11-19 17:25:17.554219      CH  Zurich    47.377      8.542
#
#          pm25    pm10     no2    so2      o3     co  aqi  temperature  \
# 17995  27.899  74.179  41.474  6.677  50.869  1.028  103        7.079
# 17996   2.950  47.988  42.235  2.821  35.551  0.644  105       28.734
# 17997  61.347  72.908  46.976  5.763  66.492  0.947  122       21.951
# 17998  40.722  95.152  32.957  5.524  53.193  0.868   95       24.042
# 17999  25.830  30.411  35.317  4.336  66.246  0.848   88        8.529
#
#        humidity  wind_speed
# 17995    52.443       7.452
# 17996    85.678       4.496
# 17997    72.311       9.660
# ...

# %%
df.sample()
# Out:
#                        timestamp country       city  latitude  longitude  \
# 4078  2025-11-09 16:25:17.554219      ZA  Cape Town   -33.925     18.424
#
#        pm25    pm10     no2    so2      o3   co  aqi  temperature  humidity  \
# 4078  54.34  99.617  27.487  4.257  46.173  0.4  108        7.324    25.533
#
#       wind_speed
# 4078       6.955

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 18000 entries, 0 to 17999
# Data columns (total 15 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   timestamp    18000 non-null  object
#  1   country      18000 non-null  object
#  2   city         18000 non-null  object
#  3   latitude     18000 non-null  float64
#  4   longitude    18000 non-null  float64
#  5   pm25         18000 non-null  float64
#  6   pm10         18000 non-null  float64
#  7   no2          18000 non-null  float64
#  8   so2          18000 non-null  float64
#  9   o3           18000 non-null  float64
#  10  co           18000 non-null  float64
#  11  aqi          18000 non-null  int64
#  12  temperature  18000 non-null  float64
#  13  humidity     18000 non-null  float64
#  14  wind_speed   18000 non-null  float64
# dtypes: float64(11), int64(1), object(3)
# memory usage: 2.1+ MB

# %%
df.describe()
# Out:
#            latitude     longitude          pm25          pm10           no2  \
# count  18000.000000  18000.000000  18000.000000  18000.000000  18000.000000
# mean      23.065980     37.655560     40.369131     70.152228     32.055176
# std       26.156536     78.600701     17.647450     24.999440     13.820680
# min      -37.814000   -123.121000      0.025000      0.061000      0.013000
# 25%       12.972000      2.352000     27.904500     53.125500     22.362500
# 50%       29.232000     42.146000     40.286500     69.961000     32.019500
# 75%       41.008000    103.820000     52.436250     87.256500     41.364250
# max       60.170000    174.763000    115.683000    161.810000     90.019000
#
#                 so2            o3            co           aqi   temperature  \
# count  18000.000000  18000.000000  18000.000000  18000.000000  18000.000000
# mean       6.035508     48.065100      0.800595    104.645556     21.510251
# ...

# %%
df.nunique()
# Out:
# timestamp        360
# country           38
# city              50
# latitude          50
# longitude         50
# pm25           15839
# pm10           16332
# no2            15139
# so2             8158
# o3             15275
# co              1376
# aqi              178
# temperature    13930
# humidity       15725
# wind_speed      8058
# dtype: int64

# %%
df.shape
# Out:
# (18000, 15)

# %%
df.columns
# Out:
# Index(['timestamp', 'country', 'city', 'latitude', 'longitude', 'pm25', 'pm10',
#        'no2', 'so2', 'o3', 'co', 'aqi', 'temperature', 'humidity',
#        'wind_speed'],
#       dtype='object')

# %%
df.dtypes
# Out:
# timestamp       object
# country         object
# city            object
# latitude       float64
# longitude      float64
# pm25           float64
# pm10           float64
# no2            float64
# so2            float64
# o3             float64
# co             float64
# aqi              int64
# temperature    float64
# humidity       float64
# wind_speed     float64
# dtype: object

# %%
df["timestamp"]
# Out:
# 0        2025-11-04 18:25:17.554219
# 1        2025-11-04 19:25:17.554219
# 2        2025-11-04 20:25:17.554219
# 3        2025-11-04 21:25:17.554219
# 4        2025-11-04 22:25:17.554219
#                     ...
# 17995    2025-11-19 13:25:17.554219
# 17996    2025-11-19 14:25:17.554219
# 17997    2025-11-19 15:25:17.554219
# 17998    2025-11-19 16:25:17.554219
# 17999    2025-11-19 17:25:17.554219
# Name: timestamp, Length: 18000, dtype: object

# %%
df[["city","latitude"]]
# Out:
#            city  latitude
# 0      New York    40.713
# 1      New York    40.713
# 2      New York    40.713
# 3      New York    40.713
# 4      New York    40.713
# ...         ...       ...
# 17995    Zurich    47.377
# 17996    Zurich    47.377
# 17997    Zurich    47.377
# 17998    Zurich    47.377
# 17999    Zurich    47.377
#
# [18000 rows x 2 columns]

# %%
df.loc[0]
# Out:
# timestamp      2025-11-04 18:25:17.554219
# country                                US
# city                             New York
# latitude                           40.713
# longitude                         -74.006
# pm25                               50.295
# pm10                              108.938
# no2                                27.998
# so2                                 6.539
# o3                                 52.568
# co                                  1.096
# aqi                                   108
# temperature                        18.504
# humidity                           70.168
# wind_speed                          3.725
# Name: 0, dtype: object

# %%
df.loc[0:3]
# Out:
#                     timestamp country      city  latitude  longitude    pm25  \
# 0  2025-11-04 18:25:17.554219      US  New York    40.713    -74.006  50.295
# 1  2025-11-04 19:25:17.554219      US  New York    40.713    -74.006  32.083
# 2  2025-11-04 20:25:17.554219      US  New York    40.713    -74.006  42.250
# 3  2025-11-04 21:25:17.554219      US  New York    40.713    -74.006  30.403
#
#       pm10     no2    so2      o3     co  aqi  temperature  humidity  \
# 0  108.938  27.998  6.539  52.568  1.096  108       18.504    70.168
# 1   63.043  36.120  4.021  43.536  1.075   90        5.838    80.088
# 2   82.553  26.935  9.538  23.320  0.977   84       31.833    62.783
# 3   79.951  63.536  7.609  31.369  0.230  158       23.140    89.153
#
#    wind_speed
# 0       3.725
# 1       8.969
# 2       9.650
# 3       8.956

# %%
df.loc[0:, "country"]
# Out:
# 0        US
# 1        US
# 2        US
# 3        US
# 4        US
#          ..
# 17995    CH
# 17996    CH
# 17997    CH
# 17998    CH
# 17999    CH
# Name: country, Length: 18000, dtype: object

# %%
df.iloc[0]
# Out:
# timestamp      2025-11-04 18:25:17.554219
# country                                US
# city                             New York
# latitude                           40.713
# longitude                         -74.006
# pm25                               50.295
# pm10                              108.938
# no2                                27.998
# so2                                 6.539
# o3                                 52.568
# co                                  1.096
# aqi                                   108
# temperature                        18.504
# humidity                           70.168
# wind_speed                          3.725
# Name: 0, dtype: object

# %%
df.iloc[4:7]
# Out:
#                     timestamp country      city  latitude  longitude    pm25  \
# 4  2025-11-04 22:25:17.554219      US  New York    40.713    -74.006  21.083
# 5  2025-11-04 23:25:17.554219      US  New York    40.713    -74.006  31.242
# 6  2025-11-05 00:25:17.554219      US  New York    40.713    -74.006  77.690
#
#      pm10     no2    so2      o3     co  aqi  temperature  humidity  \
# 4  66.423  38.997  6.919  45.615  1.085   97       13.632    76.499
# 5  92.779  30.633  8.030  43.725  0.347   92       15.159    42.505
# 6  65.198  20.302  7.641  62.687  0.734  155       36.729    47.651
#
#    wind_speed
# 4       4.017
# 5       1.199
# 6       4.542

# %%
df.iloc[0,2]
# Out:
# 'New York'

# %%
df.at[0,"city"]
# Out:
# 'New York'

# %%
df.iat[0,2]
# Out:
# 'New York'

# %%
df[(df['aqi']>90) &(df['aqi']<100)]
# Out:
#                         timestamp country      city  latitude  longitude  \
# 4      2025-11-04 22:25:17.554219      US  New York    40.713    -74.006
# 5      2025-11-04 23:25:17.554219      US  New York    40.713    -74.006
# 10     2025-11-05 04:25:17.554219      US  New York    40.713    -74.006
# 11     2025-11-05 05:25:17.554219      US  New York    40.713    -74.006
# 15     2025-11-05 09:25:17.554219      US  New York    40.713    -74.006
# ...                           ...     ...       ...       ...        ...
# 17977  2025-11-18 19:25:17.554219      CH    Zurich    47.377      8.542
# 17989  2025-11-19 07:25:17.554219      CH    Zurich    47.377      8.542
# 17992  2025-11-19 10:25:17.554219      CH    Zurich    47.377      8.542
# 17994  2025-11-19 12:25:17.554219      CH    Zurich    47.377      8.542
# 17998  2025-11-19 16:25:17.554219      CH    Zurich    47.377      8.542
#
#          pm25    pm10     no2     so2      o3     co  aqi  temperature  \
# ...

# %%
df2=df.query('aqi >90 and aqi<100')
df2
df2.reset_index()
# Out:
#       index                   timestamp country      city  latitude  \
# 0         4  2025-11-04 22:25:17.554219      US  New York    40.713
# 1         5  2025-11-04 23:25:17.554219      US  New York    40.713
# 2        10  2025-11-05 04:25:17.554219      US  New York    40.713
# 3        11  2025-11-05 05:25:17.554219      US  New York    40.713
# 4        15  2025-11-05 09:25:17.554219      US  New York    40.713
# ...     ...                         ...     ...       ...       ...
# 2506  17977  2025-11-18 19:25:17.554219      CH    Zurich    47.377
# 2507  17989  2025-11-19 07:25:17.554219      CH    Zurich    47.377
# 2508  17992  2025-11-19 10:25:17.554219      CH    Zurich    47.377
# 2509  17994  2025-11-19 12:25:17.554219      CH    Zurich    47.377
# 2510  17998  2025-11-19 16:25:17.554219      CH    Zurich    47.377
#
#       longitude    pm25    pm10     no2     so2      o3     co  aqi  \
# 0       -74.006  21.083  66.423  38.997   6.919  45.615  1.085   97
# ...

# %%
value=97
df.query('aqi==@value')
# Out:
#                         timestamp country         city  latitude  longitude  \
# 4      2025-11-04 22:25:17.554219      US     New York    40.713    -74.006
# 91     2025-11-08 13:25:17.554219      US     New York    40.713    -74.006
# 118    2025-11-09 16:25:17.554219      US     New York    40.713    -74.006
# 294    2025-11-17 00:25:17.554219      US     New York    40.713    -74.006
# 361    2025-11-04 19:25:17.554219      US  Los Angeles    34.052   -118.244
# ...                           ...     ...          ...       ...        ...
# 17724  2025-11-08 06:25:17.554219      CH       Zurich    47.377      8.542
# 17733  2025-11-08 15:25:17.554219      CH       Zurich    47.377      8.542
# 17738  2025-11-08 20:25:17.554219      CH       Zurich    47.377      8.542
# 17805  2025-11-11 15:25:17.554219      CH       Zurich    47.377      8.542
# 17878  2025-11-14 16:25:17.554219      CH       Zurich    47.377      8.542
#
# ...

# %%
df.isnull()
# Out:
#        timestamp  country   city  latitude  longitude   pm25   pm10    no2  \
# 0          False    False  False     False      False  False  False  False
# 1          False    False  False     False      False  False  False  False
# 2          False    False  False     False      False  False  False  False
# 3          False    False  False     False      False  False  False  False
# 4          False    False  False     False      False  False  False  False
# ...          ...      ...    ...       ...        ...    ...    ...    ...
# 17995      False    False  False     False      False  False  False  False
# 17996      False    False  False     False      False  False  False  False
# 17997      False    False  False     False      False  False  False  False
# 17998      False    False  False     False      False  False  False  False
# 17999      False    False  False     False      False  False  False  False
#
#          so2     o3     co    aqi  temperature  humidity  wind_speed
# ...

# %%
df_renamed = df.rename(columns={"city": "City", "country": "Country"})
print(df_renamed)
# Out:
#                         timestamp Country      City  latitude  longitude  \
# 0      2025-11-04 18:25:17.554219      US  New York    40.713    -74.006
# 1      2025-11-04 19:25:17.554219      US  New York    40.713    -74.006
# 2      2025-11-04 20:25:17.554219      US  New York    40.713    -74.006
# 3      2025-11-04 21:25:17.554219      US  New York    40.713    -74.006
# 4      2025-11-04 22:25:17.554219      US  New York    40.713    -74.006
# ...                           ...     ...       ...       ...        ...
# 17995  2025-11-19 13:25:17.554219      CH    Zurich    47.377      8.542
# 17996  2025-11-19 14:25:17.554219      CH    Zurich    47.377      8.542
# 17997  2025-11-19 15:25:17.554219      CH    Zurich    47.377      8.542
# 17998  2025-11-19 16:25:17.554219      CH    Zurich    47.377      8.542
# 17999  2025-11-19 17:25:17.554219      CH    Zurich    47.377      8.542
#
#          pm25     pm10     no2    so2      o3     co  aqi  temperature  \
# ...

# %%
df_renamed
# Out:
#                         timestamp Country      City  latitude  longitude  \
# 0      2025-11-04 18:25:17.554219      US  New York    40.713    -74.006
# 1      2025-11-04 19:25:17.554219      US  New York    40.713    -74.006
# 2      2025-11-04 20:25:17.554219      US  New York    40.713    -74.006
# 3      2025-11-04 21:25:17.554219      US  New York    40.713    -74.006
# 4      2025-11-04 22:25:17.554219      US  New York    40.713    -74.006
# ...                           ...     ...       ...       ...        ...
# 17995  2025-11-19 13:25:17.554219      CH    Zurich    47.377      8.542
# 17996  2025-11-19 14:25:17.554219      CH    Zurich    47.377      8.542
# 17997  2025-11-19 15:25:17.554219      CH    Zurich    47.377      8.542
# 17998  2025-11-19 16:25:17.554219      CH    Zurich    47.377      8.542
# 17999  2025-11-19 17:25:17.554219      CH    Zurich    47.377      8.542
#
#          pm25     pm10     no2    so2      o3     co  aqi  temperature  \
# ...

# %%
df_reordered = df[["city", "country", "timestamp"]]
df_reordered
# Out:
#            city country                   timestamp
# 0      New York      US  2025-11-04 18:25:17.554219
# 1      New York      US  2025-11-04 19:25:17.554219
# 2      New York      US  2025-11-04 20:25:17.554219
# 3      New York      US  2025-11-04 21:25:17.554219
# 4      New York      US  2025-11-04 22:25:17.554219
# ...         ...     ...                         ...
# 17995    Zurich      CH  2025-11-19 13:25:17.554219
# 17996    Zurich      CH  2025-11-19 14:25:17.554219
# 17997    Zurich      CH  2025-11-19 15:25:17.554219
# 17998    Zurich      CH  2025-11-19 16:25:17.554219
# 17999    Zurich      CH  2025-11-19 17:25:17.554219
#
# [18000 rows x 3 columns]

# %%
df
# Out:
#                         timestamp country      city  latitude  longitude  \
# 0      2025-11-04 18:25:17.554219      US  New York    40.713    -74.006
# 1      2025-11-04 19:25:17.554219      US  New York    40.713    -74.006
# 2      2025-11-04 20:25:17.554219      US  New York    40.713    -74.006
# 3      2025-11-04 21:25:17.554219      US  New York    40.713    -74.006
# 4      2025-11-04 22:25:17.554219      US  New York    40.713    -74.006
# ...                           ...     ...       ...       ...        ...
# 17995  2025-11-19 13:25:17.554219      CH    Zurich    47.377      8.542
# 17996  2025-11-19 14:25:17.554219      CH    Zurich    47.377      8.542
# 17997  2025-11-19 15:25:17.554219      CH    Zurich    47.377      8.542
# 17998  2025-11-19 16:25:17.554219      CH    Zurich    47.377      8.542
# 17999  2025-11-19 17:25:17.554219      CH    Zurich    47.377      8.542
#
#          pm25     pm10     no2    so2      o3     co  aqi  temperature  \
# ...

# %%
df["aqi"].hist()
# Out:
# <Axes: >

# %%
df.plot(kind="scatter",x="aqi",y="latitude")
# Out:
# <Axes: xlabel='aqi', ylabel='latitude'>
