# %%
import json

# %%
#to load the data
def load_data(filename):
    with open(filename,"r") as f:
        data=json.load(f)
    return data

data=load_data("store_data.json")
print(data)
# Out:
# [{'name': 'Alice', 'rating': '5 ', 'feedback': 'Great product!!', 'age': '25'}, {'name': 'Bob', 'rating': 'four', 'feedback': 'ok but late Delivery', 'age': '30'}, {'name': ' Charlie', 'rating': 'two', 'feedback': 'BAD EXPERIENCE '}, {'name': 'Diana', 'feedback': 'Loved it!', 'rating': '5', 'age': '28'}, {'name': 'Eve', 'rating': '3.5', 'feedback': 'Average - could be better', 'age': '20'}, {'name': 'Alice', 'rating': '5', 'feedback': 'Great product again!', 'age': '25'}]

# %%
#clean and structure the data
def clean_data(data):
    text_to_num={"one": 1,"two": 2,"three": 3,"four": 4,"five": 5}
    cleaned_data=[]
    unique_users=set()
    
    for user in data:
        #clean ratings
        raw_rating=str(user["rating"]).strip().lower()
        if(raw_rating in text_to_num):
            raw_rating=text_to_num[raw_rating]
        user["rating"]=raw_rating


        #handle missing values
        raw_age=user.get("age")#if age present it will return thr value else if age key does not exist will return None
        if(raw_age==None):
            user["age"]=None
            
        #handling duplicate data
        if(user["name"].strip() in unique_users):
            continue
        unique_users.add(user["name"])
        cleaned_data.append(user)
    return cleaned_data

# %%
data=clean_data(data)

# %%
def get_insights(data):
    #for avg rating
    total_rating=0
    for user in data:
        total_rating+=float(user["rating"])
    avg_rating=total_rating/len(data)
    print(f"Avereage rating of users are {avg_rating}.")


    #percentage of user with poor rating
    tot_user=0
    for user in data:
        if(float(user["rating"])<3):
            tot_user+=1
    percent_user=(tot_user/len(data))*100
    print(f"Percentage of users with poor rating are {percent_user}%.")

# %%
get_insights(data)
# Out:
# Avereage rating of users are 3.9.
# Percentage of users with poor rating are 20.0%.

# %%
def get_recommendations(data):
    recommendations=[]
    for user in data:
        curr_recom={}
        curr_recom["name"]=user["name"]
        if(float(user["rating"])>=4):
            curr_recom["brand"]="Apple"
        else:
            curr_recom["brand"]="Samsung"
        recommendations.append(curr_recom)
    return recommendations

# %%
get_recommendations(data)
# Out:
# [{'name': 'Alice', 'brand': 'Apple'},
#  {'name': 'Bob', 'brand': 'Apple'},
#  {'name': ' Charlie', 'brand': 'Samsung'},
#  {'name': 'Diana', 'brand': 'Apple'},
#  {'name': 'Eve', 'brand': 'Samsung'}]

# %%
import json

def write_data(filename, data):
    with open(filename, "w") as f:
        json.dump(data, f)

write_data("store_data.json", data)
